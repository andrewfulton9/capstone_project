# %%
from collections import Counter
import boto
import os
import time

# %%
pwd
# Out:
# u'/Users/andrew/Dropbox/Galvanize/capstone_project'

# %%
os.chdir('tests')

# %%
#os.chdir('images')

d = 'images/'
for f in os.listdir(d):
    fi = d + f
    os.remove(fi)

# %%
run ImageScrapeTest.py

# %%
w.pic_url_list
# Out:
# []

# %%
w.pic_info_list
# Out:
# []

# %%
w.folder_main_dir_prefix
# Out:
# 'images'

# %%
w.target_url_str
# Out:
# 'https://www.google.com.sg/search?q=travel&source=lnms&tbm=isch&sa=X&ei=0eZEVbj3IJG5uATalICQAQ&ved=0CAcQ_AUoAQ&biw=939&bih=591'

# %%
w.g_search_key
# Out:
# 'travel'

# %%
w.image_dl_per_search
# Out:
# 200

# %% [raw]
# w.page_source

# %%
from pattern.web import URL, extension, cache, plaintext, Newsfeed, DOM

# %%
dom = DOM(w.page_source)

# %%
dom
# Out:
# Document()

# %%
tag_list = dom('a.rg_1')

# %%
tag_list
# Out:
# []

# %%
run travel_img_extract.py

# %%
ls = set()
for key in d:
    for value in d[key]:
        print value
# Out:
# 36-bridgesunset6.jpg
# 36-dragon1.jpg
# 36-nathanroadnight2.jpg
# 36-temple1.jpg
# 36-temple4.jpg
# 36-templeentrance.jpg
# 37-buddah1.jpg
# 37-hkskyline1.jpg
# 37-hkskyline4.jpg
# 37-hkskylinedetails2.jpg
# 37-hkskylinenightpano2.jpg
# 037-lion.jpg
# 41-hongkong1.jpg
# 41-hongkongstreet2.jpg
# 41-hongkongstreet3.jpg
# 41-hongkongtowers1.jpg
# 49-bigbuddah1.jpg
# 49-bigbuddah2.jpg
# 49-innertemple3.jpg
# bigbuddah9524.jpg
# bigbuddah9526.jpg
# bigbuddah9527.jpg
# bigbuddah9539.jpg
# hongkongfrompeak9494.jpg
# hongkongisland9483.jpg
# nightimehongkong9505.jpg
# nightimehongkong9516.jpg
# nighttimehongkong9504.jpg
# bluewater6081.jpg
# boat6013.jpg
# boathouse6029.jpg
# bridge6000.jpg
# coast6005.jpg
# coast6071.jpg
# coast6072.jpg
# coastline6073.jpg
# coastline6075.jpg
# crystalclearwater6077.jpg
# floats6035.jpg
# floats6036.jpg
# hammock6021.jpg
# house6041.jpg
# house6069.jpg
# IMGP6084.jpg
# IMGP6086.jpg
# jetty6037.jpg
# jungle6064.jpg
# lighthouse5971.jpg
# mangroves6038.jpg
# ...

# %%
len(all_imgs)
# Out:
# 642

# %%
list(col_urls)[0]
# Out:
# u'http://photoeverywhere.co.uk/east/hongkong'

# %%
soup.find_all('img')
# Out:
# [<img alt="" class="animated bounceInDown" src="res/img/logo.png"/>,
#  <img alt="" src="res/img/large/1.jpg"/>,
#  <img alt="" src="res/img/large/2.jpg"/>,
#  <img alt="" src="res/img/large/3.jpg"/>,
#  <img alt="" src="res/img/large/4.jpg"/>,
#  <img alt="new" height="11" src="images/new.gif" width="28"/>,
#  <img alt="" class="tile-image" src="res/img/illustrations/map.png"/>,
#  <img alt="" class="tile-image" src="res/img/illustrations/compass.png"/>,
#  <img alt="" class="tile-image" src="res/img/illustrations/retina.png"/>,
#  <img alt="simple to use images" class="tile-image" src="res/img/illustrations/clipboard.png"/>,
#  <img alt="Creative Commons License" src="http://i.creativecommons.org/l/by/2.5/88x31.png" style="border-width: 0"/>,
#  <img alt="london" src="res/img/preview/london.jpg"/>,
#  <img alt="fiji" src="res/img/preview/fiji.jpg"/>,
#  <img alt="images of australia" src="res/img/preview/australia.jpg"/>,
# ...

# %%
for url in url_list:
    print type(url)
# Out:
# <type 'unicode'>

# %%
import urllib

# %%
os.chdir('..')

# %%
os.listdir('.')
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'images',
#  'ImageScrapeTest.py',
#  'scrap.ipynb',
#  'scrape_cars.py',
#  'selenium_test',
#  'travel_img_extract.py']

# %%
run scrape_cars.py

# %%
img_urls
# Out:
# {u'http://farm1.static.flickr.com/10/11138922_a56046a035_m.jpg',
#  u'http://farm1.static.flickr.com/10/15477661_60d9696bec_m.jpg',
#  u'http://farm1.static.flickr.com/100/293227146_abfaf5417f_m.jpg',
#  u'http://farm1.static.flickr.com/101/296807472_c3c84f5d02_m.jpg',
#  u'http://farm1.static.flickr.com/102/366993853_b4b9cc7727_m.jpg',
#  u'http://farm1.static.flickr.com/105/296665668_5413cfcd5a_m.jpg',
#  u'http://farm1.static.flickr.com/105/299523678_389f8d19ba_m.jpg',
#  u'http://farm1.static.flickr.com/110/261115038_dbf52541d7_m.jpg',
#  u'http://farm1.static.flickr.com/112/287494111_3fa42f3f30_m.jpg',
#  u'http://farm1.static.flickr.com/113/297599225_7bdf6ff5d3_m.jpg',
#  u'http://farm1.static.flickr.com/120/268726729_0b40dc7bba_m.jpg',
#  u'http://farm1.static.flickr.com/131/367912847_603fa81044_m.jpg',
#  u'http://farm1.static.flickr.com/141/385988889_774abc40a3_m.jpg',
#  u'http://farm1.static.flickr.com/146/357413879_5caa2bb39a_m.jpg',
# ...

# %%
imgs = soup.find_all('img')

# %%
imgs
# Out:
# [<img alt="Car" src="http://farm7.static.flickr.com/6007/5982607204_0ab3a49387_m.jpg" style=""/>,
#  <img alt="Cars" src="http://farm4.static.flickr.com/3356/3451826687_a3709fb753_m.jpg" style=""/>,
#  <img alt="Cars" src="http://farm4.static.flickr.com/3158/2547499193_656e5c51a0_m.jpg" style=""/>,
#  <img alt="Devon and Cornwall Police WA07ACU" src="http://farm3.static.flickr.com/2557/3662588448_669779440a_m.jpg" style=""/>,
#  <img alt="Gumball 14" src="http://farm4.static.flickr.com/3860/14427891465_8b348910e5_m.jpg" style=""/>,
#  <img alt="My New Car" src="http://farm5.static.flickr.com/4110/4991087871_6f38341939_m.jpg" style=""/>,
#  <img alt="Gumball8" src="http://farm4.static.flickr.com/3853/14375012642_ff95d93dea_m.jpg" style=""/>,
#  <img alt="Old Woody" src="http://farm4.static.flickr.com/3926/15055087520_2f31b5a87f_m.jpg" style=""/>,
#  <img alt="my dad's old car" src="http://farm9.static.flickr.com/8524/8532700242_72ddc95a1c_m.jpg" style=""/>,
# ...

# %%
len(os.listdir('images'))
# Out:
# 50

# %%
a = [1,2,3]
b = [4,5,6]

c = a+b

# %%
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
run scrape_homes.py
# Out:
# scraping 0 - 100
# sleeping
# scraping 100 - 200
# sleeping
# scraping 200 - 300
# sleeping
# scraping 300 - 400
# sleeping
# scraping 400 - 500
# sleeping
# scraping 500 - 600
# sleeping
# scraping 600 - 700
# sleeping
# scraping 700 - 800
# sleeping
# scraping 800 - 900
# sleeping
# scraping 900 - 1000
# sleeping
# scraping 1000 - 1100
# sleeping
# scraping 1100 - 1200
# sleeping
# scraping 1200 - 1300
# sleeping
# scraping 1300 - 1400
# sleeping
# scraping 1400 - 1500
# sleeping
# scraping 1500 - 1600
# sleeping
# scraping 1600 - 1700
# sleeping
# scraping 1700 - 1800
# sleeping
# scraping 1800 - 1900
# sleeping
# scraping 1900 - 2000
# sleeping
# scraping 2000 - 2100
# sleeping
# scraping 2100 - 2200
# sleeping
# scraping 2200 - 2300
# sleeping
# scraping 2300 - 2400
# sleeping
# scraping 2400 - 2500
# sleeping
# scraping 2500 - 2600
# sleeping
# scraping 2600 - 2700
# sleeping
# scraping 2700 - 2800
# sleeping
# scraping 2800 - 2900
# sleeping
# scraping 2900 - 3000
# sleeping
# ...

# %%
scrape.pages2scrape
# Out:
# 101

# %%
scrape.site
# Out:
# 'https://www.dreamstime.com/search.php?srh_field=travel&s_ph=y&s_il=y&s_rf=y&s_ed=y&s_clc=y&s_clm=y&s_orp=y&s_ors=y&s_orl=y&s_orw=y&s_st=new&s_sm=all&s_rsf=0&s_rst=7&s_mrg=1&s_sl0=y&s_sl1=y&s_sl2=y&s_sl3=y&s_sl4=y&s_sl5=y&s_mrc1=y&s_mrc2=y&s_mrc3=y&s_mrc4=y&s_mrc5=y&s_exc=&items=1000&pg=1'

# %%
len(scrape.all_urls)
# Out:
# 9074

# %%
scrape.download_move()
# Out:
# scraping 0 - 100
# sleeping
# scraping 100 - 200
# sleeping
# scraping 200 - 300
# sleeping
# ---------------------------------------------------------
# KeyboardInterrupt       Traceback (most recent call last)
# <ipython-input-437-36c984a5c4c6> in <module>()
# ----> 1 scrape.download_move()
#
# /Users/andrew/Dropbox/Galvanize/capstone_project/tests/scrape_homes.py in download_move(self)
#     111             print 'sleeping'
#     112             self.transfer_2_s3()
# --> 113             time.sleep(30)
#     114             self.empty_image_dir()
#     115
#
# KeyboardInterrupt:

# %%
# scrape.get_img_urls_many_pages()
# print '\n\n\n\n'
len(scrape.all_urls)
# Out:
# 4003

# %%
site_urls
# Out:
# {u'https://thumbs.dreamstime.com/t/helping-hands-isolated-illustrated-logo-design-53834873.jpg',
#  u'https://thumbs.dreamstime.com/t/baby-girl-reading-book-15932845.jpg',
#  u'https://thumbs.dreamstime.com/t/american-flag-closeup-white-stars-blue-background-close-up-view-bright-stitched-brilliant-colorful-41492675.jpg',
#  u'https://thumbs.dreamstime.com/t/old-streets-rome-28355906.jpg',
#  u'https://thumbs.dreamstime.com/images2012/logo.png',
#  u'https://thumbs.dreamstime.com/t/woman-exhausted-her-life-who-work-care-house-stressed-workload-36573061.jpg',
#  u'https://thumbs.dreamstime.com/t/modern-bathroom-shower-bathtub-marble-tile-open-walk-daytime-also-shows-view-yellow-house-tree-35055823.jpg',
#  u'https://thumbs.dreamstime.com/t/woman-reading-bed-book-her-morning-65600227.jpg',
#  u'https://thumbs.dreamstime.com/t/happy-family-mother-baby-playing-under-blanket-smiling-33462191.jpg',
# ...

# %%
os.listdir('../../../../Desktop/CapstoneImages/Home/dreamstime/')
# Out:
# []

# %%
ls = imgs.get_img_urls_page('https://www.dreamstime.com/search.php?srh_field=house&s_ph=y&s_il=y&s_rf=y&s_ed=y&s_clc=y&s_clm=y&s_orp=y&s_ors=y&s_orl=y&s_orw=y&s_st=new&s_sm=all&s_rsf=0&s_rst=7&s_mrg=1&s_sl0=y&s_sl1=y&s_sl2=y&s_sl3=y&s_sl4=y&s_sl5=y&s_mrc1=y&s_mrc2=y&s_mrc3=y&s_mrc4=y&s_mrc5=y&s_exc=&items=1000&pg=1')
# Out:
# url:  https://www.dreamstime.com/search.php?srh_field=house&s_ph=y&s_il=y&s_rf=y&s_ed=y&s_clc=y&s_clm=y&s_orp=y&s_ors=y&s_orl=y&s_orw=y&s_st=new&s_sm=all&s_rsf=0&s_rst=7&s_mrg=1&s_sl0=y&s_sl1=y&s_sl2=y&s_sl3=y&s_sl4=y&s_sl5=y&s_mrc1=y&s_mrc2=y&s_mrc3=y&s_mrc4=y&s_mrc5=y&s_exc=&items=1000&pg=1

# %%
len(ls)
# Out:
# 1005

# %%
access_key = os.environ['AWS_ACCESS_KEY_ID1']
access_secret_key = os.environ['AWS_SECRET_ACCESS_KEY1']

# %%
conn = boto.connect_s3(access_key, access_secret_key)

bucket_name = 'ajfcapstonehome'

b = conn.get_bucket(bucket_name)

# %%
[f.name for f in b.list()]
# Out:
# [u'100-seamless-tiling-stone-wall-1626877.jpg',
#  u'100-universal-icons-web-mobile-28223456.jpg',
#  u'1000-calory-3302309.jpg',
#  u'1970-s-family-photo-6381575.jpg',
#  u'3d-blueprint-house-15426780.jpg',
#  u'3d-energy-ratings-8713942.jpg',
#  u'3d-house-12664813.jpg',
#  u'3d-house-17410769.jpg',
#  u'3d-house-18332054.jpg',
#  u'3d-house-blueprint-2645109.jpg',
#  u'3d-house-blueprint-6732614.jpg',
#  u'3d-house-isolated-white-background-17320603.jpg',
#  u'3d-model-house-8831394.jpg',
#  u'3d-sketch-house-5391201.jpg',
#  u'3d-small-people-glass-house-20105679.jpg',
#  u'460-grey-icons-29535258.jpg',
#  u'70s-wallpaper-pattern-28079201.jpg',
#  u'abandoned-27899354.jpg',
#  u'abandoned-gym-19840955.jpg',
#  u'abandoned-hallway-19646108.jpg',
#  u'abandoned-haunted-house-hill-ghost-21391885.jpg',
#  u'abandoned-house-1251894.jpg',
#  u'abandoned-mansion-old-run-down-night-star-trails-35774067.jpg',
#  u'abandoned-old-house-home-improvement-needed-4782383.jpg',
# ...

# %%
https://www.dreamstime.com/search.php?srh_field=home&s_ph=y&s_il=y&s_rf=y&s_ed=y&s_clc=y&s_clm=y&s_orp=y&s_ors=y&s_orl=y&s_orw=y&s_st=new&s_sm=all&s_rsf=0&s_rst=7&s_mrg=1&s_sl0=y&s_sl1=y&s_sl2=y&s_sl3=y&s_sl4=y&s_sl5=y&s_mrc1=y&s_mrc2=y&s_mrc3=y&s_mrc4=y&s_mrc5=y&s_exc=&items=1000&pg=1
